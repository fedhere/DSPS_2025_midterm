# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/DSPS_2025_midterm/blob/main/DSPSmidterm2025_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # READ THESE INSTRUCTIONS CAREFULLY AND IN FULL BEFORE YOU PROCEED TO WORK!
#
# ### CONTEXT :  Investigation of the nature of stellar explosions. Side note: I know I promised examples in other areas of physics than astro, but astrophysicists have really adopted open science and reproducibility practices beyond other areas of physics and there are few open curated datasets to support analysis suitable for this level work.
#
# 10 stars explode every second in the sky, most of them unseen as they are too far for their light to reach us and definitely too far to see the star before the explosion. Stars collapse and explode, merge and explode, and stars of different nature lead to different explosion properties. We often play a game stellar foresics, trying to figure out what star and why blew off from the explosion properties.
#
# We see emission from stellar explosions in different energy regimes from different instruments and observatories.
# A new observatory, the Einstein Probe, opened an observational window in the soft X-ray dynamic sky, enabling discoveries of rapid X-ray transients.
#
# Long duration GRBs, which are understood to be explosions and mergers of massive stars, are expected to emit in X-ray, but only a fraction of the transients detected by EP were associated with Gamma Ray emission (as observed by other telescopes from the same region of the sky). Sometimes we do not detect the GRB because we are not looking in the right place, or they are too faint. This raises the question: are these soft, rapid X-ray emissions simply a manifestation of long duration Gamma Ray Bursts in X-ray wavelength? or are they different transients altogether? _That would be exciting! we may have discovered a new physical phenomenon! but how do we make sure?_
#
# Connor et al. 2025 [https://arxiv.org/pdf/2509.07141#page=8.87] approached the problem this way: they found a comprehensive datasets of long duration Gamma Ray Bursts (Connor et al. 2022) and a dataset of short Gamma Ray Bursts (https://www.mpe.mpg.de/~jcg/grbgen.html), a different less well understood phenomenon. They compare the spatial distribution, namely the distribution of of redshifts, which means distances from us (because all these phenomena are, as far as we can tell, randomely distributed on the plane of the sky), for these three samples and ask the question: can they be the same? and most importantly, are the distributions of EP transients with GRB and without GRB both the same as the distribution of long GRBs? if they are, it is possible we are just missing the GRB detections, but the gamma ray emission could be there for all transients detected by the EP. But if they are not, then these are two different phenomena and there may be new physics!!!
#
#
# In the files provided, you will find  the information about the EP soft X-ray transients, for the longGRB, and for the short duration GRB samples.
#
#
# ***Find a statistical answer to the question: do these sample have the same properties, statistically, as far as their spatial distribution in the Universe??***
#
# Approach this problem in a **null-hypothesis rejection framework**. Technically, the question you are asking is "are the distributions pairwise the same"?

# %% [markdown]
# # Objective: assessing differences redshift distribution of different high energy transient samples.

# %% [markdown]
# PLEASE SEE THE HINTS TO EACH TASK [here](https://docs.google.com/document/d/1KApJOkC7CWjXBhSQDavRmdhAkMD5z802zv5ikY9tw04/edit?usp=sharing) (no points loss for hints!)
#
# You will receive points for each of the marked deliverables, *and for your discussion of your findings*.
#
# ## 1-5 are the data ingestion and wrangling tasks and are worth up to 35% of the points
# *In the data wrangling portion points are awarded for data processed so that they support the analysis in parts 6-12
# This portion is likely going to be the most time consuming.*
#
# ## 6-7 are statistical exploration portion of the exercise, and are worth up to 30% of the points
# *This portion will see you assessing the statistical properties of the data which you will need to guide your analsyis. Points are awarded for printed statements with comments that interpret the numbers in the printed statement and and plots with captions that support the analysis and conclusions.**
#
# ## 8-12 are the analysis portion of the exercise (including exploratory and visual analysis), and are worth up to 38% of the points.
# *In the data analysis portion points are awarded for correct analysis, conclusions supported by the analysis* ***and expressed in full sentences***, *and plots with captions that support the analysis and conclusions.*
#
# *That sums up to 105%, but the maximum grade is reached at 100%. This means you can get 100% even with some small mistakes, and if you exceed 100% the rest will be accounted for as a modest extra credit score and help your cumulative score at the end of the semester.*
#
# ## Data Wrangling (each task is 7 points)
#
#    **For each of these steps, make sure you inspect the dataframe apprioriately!**
#
#   1. Read in the data for the Einstain Probe soft X-ray transients, make sure you identify the redshift column Redshift is often identified by the letter z. If you need more help you can go to the paper Connor+2025 (see above) (call the sample `eptransients`). Clean up the dataframe (if youa are using a dataframe) keeping only what you need (read through step 5 to make sure you are not missing anything)
#
#   2. Read in the file with the short GRB sample information (call the sample `shortGRB`). Clean up the dataframe
#
#   3. Read in the file with the long GRB sample information (call the sample `longGRB`). Clean up the dataframe
#
#   4. Separate the samples of EP transients and create a dataframe with only those with a coincident GRB detection  (call the sample `ep_GRB`)
#
#   5. Create a second EP transient sample with only no-GRB detection (call the sampleand `ep_noGRB`)
#
#
#
#
# ## Data exploration (visual and quantitative) (each task is 15 points)
#
#   6. Plot the distribution of redshifts for each of the (5) samples.
#
#   7. Calculate the central tendency of the redshift for each of the samples and its uncertainty. Discuss if the means are statistically different based on their uncertainties (add plots as appropriate, and chose your preferred way to measure the central tendency and spread)
#
# ## Analysis (visual and quantitative) (each task is 7 points unless otherwise stated)
#   8. Set up your Null Hypotesis Rejection testing framework. Remember there are 6 steps in NHRT, the first 4 are the set up and should be done here! (10 points)
#
#   9. Compare the distribution of redshifts of EP transients (all of them) with that of short GRBs with that of long GRBs. Compare the distribution of short and long GRBs as well, all  with the same, appropriate, statistical test. You want to determine if they are the same (or more exactly "extracted from the same population", hint hint...!) - are the EP transients consistent with either? with both? Establish this way if you should use the short or long GRB sample for the rest of the analysis
#
#   10. Compare the distribution of EP transients with GRB with the chosen GRB sample in step 9. What can you say?
#
#   11. Repeat the comparison of EP transients without GRB emissions to the sample chosen in step 9. What can you say?
#
#   12. Frame your final answer in terms of being able to rule out if distributions are consistent and discuss this result in the light of the initial prompt.
#
#
# **Extra Credit**. Use the Anderson Darling test which is less sensitive to the central tendency of the distribution and more to the shape of the tails.

# %%
# imports here
import pandas as pd
from scipy.stats import ks_2samp
import pylab as plt

# %% [markdown]
# ### DATA WRANGLING

# %% [markdown]
# 1. Read in the data for the Einstain Probe soft X-ray transients
# You can find the data in the github repository
#
# https://github.com/fedhere/DSPS_2025_midterm
# Clean your dataset removing all the columns you will not need in the analysis and all invalid values in the resulting dataframe
# _the deliverable in this step is a table showing the first 7 rows of the dataframe_
#
# Rename the redshift column `Redshift` if needed
#
#
# [hints](https://docs.google.com/document/d/1V9PVb6tK0yuCSTyCILkKXZD9--5PVIvhKDPZIiREdtQ/edit#heading=h.wqv9503ir8mr)
#
# You can find the solution at this URL:https://github.com/fedhere/DSPS_2023_midterm/blob/main/data/SNmetallicity_final.csv - if you use this solution you will not get the  points for this deliverable (but you can take the shortcut now and go back later to this! and if you do get the solution later you will get the points!)

# %%
eptransients = pd.read_csv("https://raw.githubusercontent.com/fedhere/DSPS_2025_midterm/refs/heads/main/data/EPtransients.csv?token=GHSAT0AAAAAADKDO3YJ7DYSKDF74MHK52KG2HESQUQ")
eptransients.shape
# Out:
# (26, 9)

# %%
eptransients = eptransients[["Name",	"Redshift",	"GRB?"]]
eptransients.head()
# Out:
#         Name  Redshift GRB?
# 0  EP240315a     4.859  GRB
# 1  EP240414a     0.401  NaN
# 2  EP240801a     1.673  XRF
# 3  EP240804a     3.662  GRB
# 4  EP240806a     2.818  NaN

# %%
eptransients.tail()
# Out:
#           Name  Redshift GRB?
# 21   EP250416a     0.963  GRB
# 22   EP250427a     1.520  GRB
# 23  EP250704ab     0.661  GRB
# 24   EP250821a     0.577  NaN
# 25   EP250827a     1.610  NaN

# %%
print("the shape of the file is {} rows and {} columns".format(*eptransients.shape))
# Out:
# the shape of the file is 26 rows and 3 columns

# %%
eptransients.describe()
# Out:
#         Redshift
# count  26.000000
# mean    2.114654
# std     1.497666
# min     0.176000
# 25%     0.801750
# 50%     1.641500
# 75%     3.208750
# max     4.859000

# %%
eptransients.to_csv("eptransients_final.csv", index=None)

# %% [markdown]
# # 2.  Read in the file with the short GRB
#
# You can find the data in the github repository.
#
# https://github.com/fedhere/DSPS_2025_midterm
# Clean your dataset of all the columns you will not need and all invalid values in the remaining dataframe
# _the deliverable is a table like the one below_
#
# Rename the redshift column `Redshift` if needed
#
# [hints](https://docs.google.com/document/d/1V9PVb6tK0yuCSTyCILkKXZD9--5PVIvhKDPZIiREdtQ/edit#heading=h.wqv9503ir8mr)
#
#
# You can get the solution at this url: https://github.com/fedhere/DSPS_2025_midterm/blob/main/data/SNmetallicity_final.csv - if you use this solution you will not get the 7 points for this deliverable (but you can go back later to this! and if you do get the solution later you will get the points!)

# %%
shortGRB = pd.read_csv("https://raw.githubusercontent.com/fedhere/DSPS_2025_midterm/refs/heads/main/data/shortGRBs.tsv?token=GHSAT0AAAAAADKDO3YJ5KRNKIV7R72VXXDO2HESTYQ", sep="\t")
shortGRB.head()
# Out:
#                     GRB  σtie  σAGb σhost  Ro (arcsec)    Ro (kpc)  \
# 0  Optical localization   NaN   NaN   NaN          NaN         NaN
# 1               091109B  0.04  0.10   ...          ...         ...
# 2               110112A  0.11  0.09   ...          ...         ...
# 3              110402Aa  0.15  0.07  0.05  0.91 ± 0.17   7.2 ± 1.3
# 4               130912A  0.06  0.30  0.04  0.68 ± 0.31  5.6 ± 2.6i
#
#   Re (arcsec)       AB Magc Host? Unnamed: 9      z  Unnamed: 11
# 0         NaN           NaN   NaN        NaN    NaN          NaN
# 1         ...        >27.3f     N      >0.2f    ...          NaN
# 2         ...        >27.3f     N     >0.45f    ...          NaN
# 3         0.7  24.24 ± 0.20     Y       0.03  0.854          NaN
# 4        0.32   26.8 ± 0.3f     Y      0.08f    ...          NaN

# %%
shortGRB.drop(0, inplace=True)
shortGRB.head()
# Out:
#         GRB  σtie  σAGb σhost  Ro (arcsec)    Ro (kpc) Re (arcsec)  \
# 1   091109B  0.04  0.10   ...          ...         ...         ...
# 2   110112A  0.11  0.09   ...          ...         ...         ...
# 3  110402Aa  0.15  0.07  0.05  0.91 ± 0.17   7.2 ± 1.3         0.7
# 4   130912A  0.06  0.30  0.04  0.68 ± 0.31  5.6 ± 2.6i        0.32
# 5   131004A  0.16  0.05  0.01  0.41 ± 0.17   3.1 ± 1.3         0.4
#
#          AB Magc Host? Unnamed: 9      z  Unnamed: 11
# 1         >27.3f     N      >0.2f    ...          NaN
# 2         >27.3f     N     >0.45f    ...          NaN
# 3   24.24 ± 0.20     Y       0.03  0.854          NaN
# 4    26.8 ± 0.3f     Y      0.08f    ...          NaN
# 5  25.80 ± 0.05f     Y      0.05f  0.717          NaN

# %%
shortGRB["Redshift"] = pd.to_numeric(shortGRB["z"], errors="coerce")
shortGRB = shortGRB[["Redshift"]]

# %%
print("the shape of the file is {} rows and {} columns".format(*shortGRB.shape))
# Out:
# the shape of the file is 32 rows and 1 columns

# %%
shortGRB.describe()
# Out:
#         Redshift
# count  14.000000
# mean    0.733286
# std     0.402159
# min     0.154000
# 25%     0.525000
# 50%     0.600000
# 75%     0.819750
# max     1.717000

# %%
shortGRB.dropna(inplace=True)

# %%
shortGRB.to_csv("shortGRB_final.csv", index=None)

# %% [markdown]
# # 3 Read in the file with the long GRB sample
#
# You can find the data in the github repository.
#
# https://github.com/fedhere/DSPS_2025_midterm
# Clean your dataset of all the columns you will not need and all invalid values in the remaining dataframe
# _the deliverable is a table like the one below_
#
# Rename the redshift column `Redshift` if needed
#
# [hint](https://docs.google.com/document/d/1V9PVb6tK0yuCSTyCILkKXZD9--5PVIvhKDPZIiREdtQ/edit#heading=h.wqv9503ir8mr)
#
#
# You can get the solution at this url: https://github.com/fedhere/DSPS_2025_midterm/blob/main/data/SNmetallicity_final.csv

# %%
longGRB = pd.read_csv("https://raw.githubusercontent.com/fedhere/DSPS_2025_midterm/refs/heads/main/data/longGRBs.csv?token=GHSAT0AAAAAADKDO3YJWARRB2OB7IR4O22O2HES2QQ",
                      skiprows=1)
longGRB
# Out:
#          GRBa    GRB X-ray position Error Instrument IPNb XAb OTb  RAb  \
# 0     250813B    22h26m55s +12° 30'     3       SVOM    y   y   y  NaN
# 1     250812A    02h10m25s -43° 04'    11       SVOM  NaN   y   y  NaN
# 2     250809A    15h32m04s -53° 17'     3      Swift  NaN   y   y  NaN
# 3     250808A    04h14m13s -22° 54'    11       SVOM    y   y   y  NaN
# 4     250807B    01h02m21s -59° 06'     3      Swift  NaN   y   y  NaN
# ...       ...                   ...   ...        ...  ...  ..  ..  ...
# 2778   970508  06h53m28s +79° 17.4'    3'    SAX/WFC  NaN   y   y    y
# 2779   970402  14h50m16s -69° 19.9'    3'    SAX/WFC  NaN   y   n    n
# 2780   970228  05h01m57s +11° 46.4'    3'    SAX/WFC    y   y   y    n
# 2781   970111  15h28m15s +19° 36.3'    3'    SAX/WFC    y   y   n    n
# 2782   960720  17h30m37s +49° 05.8'    3'    SAX/WFC  NaN   n   n    n
#
#             IAUC     zc
# 0            NaN  1.752
# 1            NaN  2.571
# 2            NaN    NaN
# ...

# %%
longGRB["Redshift"]  = pd.to_numeric(longGRB["zc"], errors="coerce")
longGRB = longGRB[["Redshift"]]

# %%
longGRB.describe()
# Out:
#          Redshift
# count  568.000000
# mean     1.995763
# std      1.384031
# min      0.008500
# 25%      0.971750
# 50%      1.713500
# 75%      2.671750
# max      8.260000

# %%
longGRB.dropna(inplace=True)
# Out:
# /tmp/ipython-input-1071831005.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   longGRB.dropna(inplace=True)

# %%
longGRB.to_csv("longGRB_final.csv", index=None)

# %% [markdown]
# # 4 Separate the samples of EP transients and create a dataframe with only those with a coincident GRB detection
#
#
# [hints](https://github.com/fedhere/DSPS_2025_midterm/blob/main/solutions/README.md)
#
# You can get the solution at this url: https://github.com/fedhere/DSPS_2025_midterm/blob/main/data/SNmetallicity_final.csv

# %%
ep_GRB = eptransients[~eptransients["GRB?"].isna()]
ep_GRB.shape
# Out:
# (12, 3)

# %%
ep_GRB.to_csv("ep_GRB_final.csv", index=None)

# %% [markdown]
# # 5 Create a second EP transient sample with only no-GRB detection
#
#
# [hint](https://docs.google.com/document/d/1KApJOkC7CWjXBhSQDavRmdhAkMD5z802zv5ikY9tw04/edit?tab=t.0#heading=h.isi30wsuhrhc)
#
#
# You can get the solution at this url: https://github.com/fedhere/DSPS_2025_midterm/blob/main/data/SNmetallicity_final.csv

# %%
ep_noGRB = eptransients[eptransients["GRB?"].isna()]
ep_noGRB.shape
# Out:
# (14, 3)

# %%
ep_noGRB.to_csv("ep_noGRB_final.csv", index=None)

# %%
#use this code to check your data file size. It should return
"""
eptransients has 26 rows
longGRB has 568 rows
shortGRB has 14 rows
ep_GRB has 12 rows
ep_noGRB has 14 rows
"""

for df,filename in zip([eptransients, longGRB, shortGRB, ep_GRB, ep_noGRB],
              ["eptransients", "longGRB", "shortGRB", "ep_GRB", "ep_noGRB"]
              ):
  print(f"{filename} has {df.shape[0]} rows")
# Out:
# eptransients has 26 rows
# longGRB has 568 rows
# shortGRB has 14 rows
# ep_GRB has 12 rows
# ep_noGRB has 14 rows

# %% [markdown]
# #### DATA EXPLORATION

# %% [markdown]
# # 6  Plot the distribution of readshifts  for each of the  samples
#
#
# remember axis labels and captions!
#
# [hint](https://docs.google.com/document/d/1KApJOkC7CWjXBhSQDavRmdhAkMD5z802zv5ikY9tw04/edit?tab=t.0#heading=h.vu3ga15gdvc0)

# %%
ax = eptransients.hist();
ep_GRB.hist(ax=ax, alpha=0.5, label="GRB");
ep_noGRB.hist(ax=ax, alpha=0.5, label="noGRB");
plt.legend()

longGRB.hist();
shortGRB.hist();

# %% [markdown]
# Distribution of redshifts for the four samples under consideration: from top to bottom: all EP transients, and the noGRB and GRB EP sample overplotted (color as in legend), long GRB and short GRB. The thing that stands out the most is that the longGRB distribution is much smoother and reseambles a poisson distribution with a tail that extends to redshift 8. But this may just be driven by the larger sample size. The other samples are much smaller and the short GRB sample in particular only extends to redshift 1.6, the EP transients to 5.

# %% [markdown]
# #  7. Calculate the mean readshift for each of the samples  and its uncertainty
#
# Ideally dont't just spit out numbers, but properly write what the numbers are in a well formatted statement. Dont overthing this task: this is a quick comparison of distribution properties. Are they obviously differnt distributions or could they be the same (statistically?). This shoudl not take you more than a few minutes
#
# ** Extra credit: make a box and whisker plot of the distributions**

# %%
ep_GRB["Redshift"].mean(), ep_GRB["Redshift"].std()
# Out:
# (np.float64(2.5608333333333335), 1.4163285336218836)

# %%
ep_noGRB["Redshift"].mean(), ep_noGRB["Redshift"].std()
# Out:
# (np.float64(1.7322142857142855), 1.5082507024094773)

# %%
longGRB["Redshift"].mean(), longGRB["Redshift"].std()
# Out:
# (np.float64(1.9957634683098593), 1.3840309536879067)

# %%
shortGRB["Redshift"].mean(), shortGRB["Redshift"].std()
# Out:
# (np.float64(0.7332857142857142), 0.40215925444289596)

# %%
eptransients["Redshift"].mean(), eptransients["Redshift"].std()
# Out:
# (np.float64(2.1146538461538458), 1.497665755562507)

# %% [markdown]
# #### ANALYSIS

# %% [markdown]
# # 8 Set up your Null Hypotesis Rejection testing framework.
#
# Describe the test you are about to run and why you choose it, and state its Null Hypothesis and weather it is rejected or not.

# %% [markdown]
# The null hypotehsis is that pairwise the distributions are the same.
#
# I will set a 2-sigma or 0.05 p-value
#
# The appripriate test for this hypothesis is the KS test.
#
# Under the KS null the distributions come from the same generative process (i.e. are the same).

# %% [markdown]
# # 9 Compare the distribution of long and short GRB, long GRBs and EP transients, short GRB and EP transients. Discuss your findings. Only the sample statistically consistent with the EP tansients sample should be used in later tasks.
#
# [hint](https://docs.google.com/document/d/1KApJOkC7CWjXBhSQDavRmdhAkMD5z802zv5ikY9tw04/edit?tab=t.0#heading=h.pwkb8bo4nrla)
#
# **Extra Credit** define a function that given the 2 samples runs and interprets the test reporting the result automatically. That way you can use it for all sample comparisons and save time! but you do not have to for the grade
#
#
# **Extra Credit** if you have chosen the right statistical test, there is a plot that goes with it and helps you visualize your findings. Add this plot (as seen in some homework)

# %%
alpha = 0.05
def kscompare(dist1, dist2):
  p = ks_2samp(dist1, dist2)[1]
  ax = dist1.hist(cumulative=True, density=True, bins=100,
                                    histtype='step')
  dist2.hist(cumulative=True, density=True, bins=100,
                                    histtype='step', ax=ax)
  print(f"the hypothesis p-value is {p}")
  if p < alpha:
    print(f"We can reject the null hypothesis that the samples are statistically the same at a p-value {alpha}")
  else:
        print(f"We cannot reject the null hypothesis that the samples are statistically the same at a p-value {alpha}")

# %%
kscompare(shortGRB, longGRB)
# Out:
# the hypothesis p-value is [1.6763869e-05]
# We can reject the null hypothesis that the samples are statistically the same at a p-value 0.05

# %%
kscompare(shortGRB, eptransients[["Redshift"]])
# Out:
# the hypothesis p-value is [0.00197579]
# We can reject the null hypothesis that the samples are statistically the same at a p-value 0.05

# %%
kscompare(longGRB, eptransients[["Redshift"]])
# Out:
# the hypothesis p-value is [0.44988298]
# We cannot reject the null hypothesis that the samples are statistically the same at a p-value 0.05

# %% [markdown]
# the EP transients are only compatible with long GRBs. We will continue the analysis with those

# %% [markdown]
# # 10. Compare the distribution of EP GRB transients with the sample you chose in step 9

# %%
kscompare(longGRB, ep_GRB[["Redshift"]])
# Out:
# the hypothesis p-value is [0.32123592]
# We cannot reject the null hypothesis that the samples are statistically the same at a p-value 0.05

# %% [markdown]
# # 11. Compare the distribution of EP with no GRB transients with the sample you chose in step 9
#
# Discuss your findings!

# %%
kscompare(longGRB, ep_noGRB[["Redshift"]])
# Out:
# the hypothesis p-value is [0.25918551]
# We cannot reject the null hypothesis that the samples are statistically the same at a p-value 0.05

# %% [markdown]
#   # 12. Frame your final answer in terms of being able to rule out if distributions are consistent and discuss this result in the light of the initial prompt.

# %% [markdown]
# Since we cannot reject the hypothesis that the EP sample with GRB detections and the one without GRB detections are statistically identical (at least in redshift distribution) then we cannot rule out that the EP sample of soft X-Ray transients is just a sample of longGRB counterparts even if we did not detect the GRB counterpart for all transients.

# %% [markdown]
#
# # Extra Credit. Use the Anderson darling instead, which unlike the KS test is not biased to the central tendency of the distribution.
