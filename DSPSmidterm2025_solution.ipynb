# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/DSPS_2025_midterm/blob/main/DSPSmidterm2025_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # READ THESE INSTRUCTIONS CAREFULLY AND IN FULL BEFORE YOU PROCEED TO WORK!

# %% [markdown]
# # DOMAIN CONTEXT :  Investigation of the nature of stellar explosions.
#
# Side note: I know I promised examples in other areas of physics than astro, but astrophysicists have really adopted open science and reproducibility practices beyond other areas of physics and there are few open curated datasets to support analysis suitable for this level work.
#
# 10 stars explode every second in the sky, most of them unseen as they are too far for their light to reach us and definitely too far to see the star before the explosion. Stars collapse and explode, merge and explode, and stars of different nature lead to different explosion properties. We often play a game stellar foresics, trying to figure out what star blew off  and why from the explosion properties.
#
# We see emission from stellar explosions in different energy regimes from different instruments and observatories.
# **A new observatory, the Einstein Probe, opened an observational window in the soft X-ray dynamic sky, enabling discoveries of rapid X-ray transients**.
#
# A fraction of the transients detected by EP were associated with Gamma Ray emission (as observed by other telescopes from the same region of the sky). But sometimes we do not detect the GRB because we are not looking in the right place, or they are too faint. Was there undetected Gamma Ray emission for all others?
#
# Long duration Gamma Ray Bursts ("_long GRBs_"), which are understood to be explosions and mergers of massive stars, are expected to emit in X-ray. This raises the question: **are these soft, rapid X-ray emissions simply a manifestation of long  GRB in X-ray wavelength? or are the ones withour GRB emission different transients altogether?** _That would be exciting! we may have discovered a new physical phenomenon! but how do we make sure?_
#
# [Connor et al. 2025](https://arxiv.org/pdf/2509.07141#page=8.87) approached the problem this way: they found a comprehensive datasets of _long GRBs_ ([Connor et al. 2022](https://academic.oup.com/mnras/article/515/4/4890/6649214)) and a dataset of _short GRBs_ (https://www.mpe.mpg.de/~jcg/grbgen.html), a different less well understood phenomenon. They compare the spatial distribution, namely the distribution of redshifts, which means distances from us because all these phenomena are, as far as we can tell, randomely distributed on the plane of the sky, for these three samples and ask the question: as far as spatial properties, are they be the same? and most importantly, are the distributions of EP transients with GRB and without GRB both the same as the known distributions of GRBs? if they are, it is possible we are just missing the GRB detections, but the gamma ray emission could be there for all transients detected by the EP. But if they are not, then these are two different phenomena and there may be new physics!!!
#
#
# In the files provided, you will find EP soft X-ray transients redshift data, the longGRB redshiftdata, and the short redshift GRB data.
#
#
# ***Find a statistical answer to the question: do these sample have the same spatial properties, statistically??***
#
# Approach this problem in a **null-hypothesis rejection framework**. Technically, the question you are asking is "are the distributions pairwise the same"?

# %% [markdown]
# # OBJECTIVE:  to assess is the redshift distribution of different high energy transient samples are the same.

# %% [markdown]
# PLEASE SEE THE HINTS TO EACH TASK [here](https://docs.google.com/document/d/1KApJOkC7CWjXBhSQDavRmdhAkMD5z802zv5ikY9tw04/edit?usp=sharing) (no points loss for hints!)
#
# You will receive points for each of the marked deliverables, *and for your discussion of your findings*.
#
# # QUICK OVERVIEW OF EACH TASK
#
# ## 1-5 are the DATA INGESTION AND WRANGLING tasks and are worth up to 35% of the points
# *In the data wrangling portion points are awarded for data processed so that they support the analysis in parts 6-12
# This portion is likely going to be the most time consuming. If it takes more than 30 minutes consider using the solution and go back to it later*
#
#    **Seven points for each task. For each of these steps, make sure you inspect the dataframe apprioriately!**
#
#   1. Read in the data for the Einstain Probe soft X-ray transients. Clean up the dataframe
#
#   2. Read in the file with the short GRB sample information. Clean up the dataframe
#
#   3. Read in the file with the long GRB sample information. Clean up the dataframe
#
#   4. Separate the samples of EP transients and create a dataframe with only those with a coincident GRB detection
#
#   5. Create a second EP transient sample with only no-GRB detection
#
# ## 6-7 are the DATA EXPLORATION portion of the exercise, and are worth up to 30% of the points
# *This portion will see you exploring the statistical properties of the data which you will need to guide your analsyis. Points are awarded for printed statements with comments that interpret the numbers in the printed statement and and plots with captions that support the conclusions. There are only two tasks and this should not take a long time (20 minutes maybe? if it is taking longer you may be overthinking it)*
#
#   **Each task is 15 points, plots rendered but wihout captions dont count**
#
#   6. Plot the distribution of redshifts for each of the (5) samples.
#
#   7. Calculate the central tendency of the redshift for each of the samples and its uncertainty. Discuss if the means are statistically different based on their general statistical properties.
#
# ## 8-12 are the ANALYSIS portion of the exercise (including exploratory and visual analysis), and are worth up to 38% of the points.
# *In the data analysis portion points are awarded for correct analysis, conclusions supported by the analysis* ***and expressed in full sentences***, *and plots with captions that support the analysis and conclusions.*
#
# *That sums up to 103%, but the maximum grade is reached at 100%. This means you can get 100% even with a couple small mistakes.*
#
#   **Each task is 7 points unless otherwise stated**
#
#   8. Set up your Null Hypotesis Rejection testing framework. (10 points)
#
#   9. Compare pairwise the distributions of redshifts of EP transients (all of them), of short GRBs, and of long GRBs to establish if you should use the short or long GRB sample for the rest of the analysis
#
#   10. Compare the distribution of EP transients with GRB with the chosen GRB sample in step 9. What can you say?
#
#   11. Repeat the comparison of EP transients without GRB emissions to the sample chosen in step 9. What can you say?
#
#   12. Discuss this result in the light of the initial prompt.

# %%
# imports here (I only needed 3 imports, but you can use however many you want)
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import ks_2samp, anderson_ksamp

# %% [markdown]
# # PART I DATA INGESTION AND WRANGLING

# %% [markdown]
# ## 1 Read in the data for the Einstain Probe soft X-ray transients
#
#
# _the deliverables in each step 1 thorough 5 are a table showing the first few rows of the dataframe, the printed shape of the dataframe, a statistical description that includes the properties of the Redshift column which needs to be a numerical type_
#
# You can find the data in the data folder in the github repository https://github.com/fedhere/DSPS_2025_midterm
#
# Make sure you identify the redshift column Redshift which may be called redshift or identified with the symbol z or zc. If you need more help you can go to the paper Connor+2025 (see above) (call the sample `eptransients`).
#
# Clean up the dataframe (if youa are using a dataframe) keeping only what you need (read through step 5 to make sure you are not missing anything)
#
#
#
# [hints](https://docs.google.com/document/d/1KApJOkC7CWjXBhSQDavRmdhAkMD5z802zv5ikY9tw04/edit?tab=t.0#heading=h.wqv9503ir8mr)

# %%
eptransients = pd.read_csv("https://raw.githubusercontent.com/fedhere/DSPS_2025_midterm/refs/heads/main/data/EPtransients.csv")
eptransients.shape
# Out:
# (26, 9)

# %%
eptransients.head()
# Out:
#         Name  Redshift GRB?         ΓWXT       FWXT,avg      FWXT,peak  \
# 0  EP240315a     4.859  GRB      240315C            1.4              ±
# 1  EP240414a     0.401  NaN  3.1+0.7−0.8  (6.5+1.3−1.0)              ×
# 2  EP240801a     1.673  XRF      240801B              2              ±
# 3  EP240804a     3.662  GRB      240804B    0.7+1.2−0.4  (6.1+0.3−0.2)
# 4  EP240806a     2.818  NaN  2.6+1.2−1.0  (1.9+1.8−0.6)              ×
#
#   References     Unnamed: 7 Unnamed: 8
# 0        0.1  (5.3+1.0−0.7)          ×
# 1      10−10           (2.2          ±
# 2        0.2           (4.8          ±
# 3          ×          10−10          –
# 4       10−9              –    (15,16)

# %%
eptransients.tail()
# Out:
#           Name  Redshift GRB?     ΓWXT     FWXT,avg FWXT,peak References  \
# 21   EP250416a     0.963  GRB  250416C  0.3+1.0−0.8      (5.7          ±
# 22   EP250427a     1.520  GRB  250427A          1.7         ±        0.4
# 23  EP250704ab     0.661  GRB  250704B          1.7         ±        1.3
# 24   EP250821a     0.577  NaN      1.2            ±       0.5       (1.3
# 25   EP250827a     1.610  NaN      0.7            ±       0.5       (1.7
#
#        Unnamed: 7 Unnamed: 8
# 21           1.8)          ×
# 22  (2.0+0.3−0.2)          ×
# 23  (1.3+0.8−1.1)          ×
# 24              ±       0.4)
# 25              ±       0.4)

# %%
eptransients.columns
# Out:
# Index(['Name', 'Redshift', 'GRB?', 'ΓWXT', 'FWXT,avg', 'FWXT,peak',
#        'References', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
eptransients = eptransients[['Name', 'Redshift', 'GRB?']]#... your code here to get to the final version of the data
eptransients.head()
# Out:
#         Name  Redshift GRB?
# 0  EP240315a     4.859  GRB
# 1  EP240414a     0.401  NaN
# 2  EP240801a     1.673  XRF
# 3  EP240804a     3.662  GRB
# 4  EP240806a     2.818  NaN

# %%
eptransients.describe() # Redshift needs to be a numerical column. if it is you will see its statistical properties in describe()
# Out:
#         Redshift
# count  26.000000
# mean    2.114654
# std     1.497666
# min     0.176000
# 25%     0.801750
# 50%     1.641500
# 75%     3.208750
# max     4.859000

# %%
print("the shape of the file is {} rows and {} columns".format(*eptransients.shape))
# Out:
# the shape of the file is 26 rows and 3 columns

# %% [markdown]
# ## 2  Read in the file with the short GRB
#
# You can find the data in the github repository.
#
# https://github.com/fedhere/DSPS_2025_midterm
#
# call the sample `shortGRB`.
#
# Clean your dataset of all the columns you will not need and all invalid values in the remaining dataframe
#
# Rename the redshift column `Redshift` if needed and ensure it is a numerical type column
#
# [hints](https://docs.google.com/document/d/1KApJOkC7CWjXBhSQDavRmdhAkMD5z802zv5ikY9tw04/edit?tab=t.0#heading=h.wqv9503ir8mr)
#
# You can get the solution at this url: https://github.com/fedhere/DSPS_2025_midterm/tree/main/solutions - if you use this solution you will not get the 7 points for this deliverable (but you can go back later to this! and if you do get the solution later you will get the points!)

# %%
shortGRB = pd.read_csv("https://raw.githubusercontent.com/fedhere/"
"DSPS_2025_midterm/refs/heads/main/data/shortGRBs.tsv", sep='\t')

shortGRB.head()
# Out:
#                     GRB  σtie  σAGb σhost  Ro (arcsec)    Ro (kpc)  \
# 0  Optical localization   NaN   NaN   NaN          NaN         NaN
# 1               091109B  0.04  0.10   ...          ...         ...
# 2               110112A  0.11  0.09   ...          ...         ...
# 3              110402Aa  0.15  0.07  0.05  0.91 ± 0.17   7.2 ± 1.3
# 4               130912A  0.06  0.30  0.04  0.68 ± 0.31  5.6 ± 2.6i
#
#   Re (arcsec)       AB Magc Host? Unnamed: 9      z  Unnamed: 11
# 0         NaN           NaN   NaN        NaN    NaN          NaN
# 1         ...        >27.3f     N      >0.2f    ...          NaN
# 2         ...        >27.3f     N     >0.45f    ...          NaN
# 3         0.7  24.24 ± 0.20     Y       0.03  0.854          NaN
# 4        0.32   26.8 ± 0.3f     Y      0.08f    ...          NaN

# %%
shortGRB = shortGRB[['z']]
shortGRB.head()
# Out:
#        z
# 0    NaN
# 1    ...
# 2    ...
# 3  0.854
# 4    ...

# %%
shortGRB.dropna(inplace=True)
shortGRB.rename({"z":"Redshift"}, axis=1, inplace=True)
shortGRB.head()
# Out:
#         z
# 3   0.854
# 5   0.717
# 6   0.600
# 10  1.717
# 14  0.450

# %%
print("the shape of the data is {} rows and {} columns".format(*shortGRB.shape))
# Out:
# the shape of the data is 14 rows and 1 columns

# %% [markdown]
# ## 3 Read in the file with the long GRB sample
#
# You can find the data in the github repository
# https://github.com/fedhere/DSPS_2025_midterm
# Clean your dataset of all the columns you will not need and all invalid values in the remaining dataframe
#
# call the sample `longGRB`
#
#
#
# Rename the redshift column `Redshift` if needed and make sure it is a numerical type
#
#
# [hints](https://docs.google.com/document/d/1KApJOkC7CWjXBhSQDavRmdhAkMD5z802zv5ikY9tw04/edit?tab=t.0#heading=h.wqv9503ir8mr)
#
# You can get the solution at this url: https://github.com/fedhere/DSPS_2025_midterm/tree/main/solutions - if you use this solution you will not get the 7 points for this deliverable (but you can go back later to this! and if you do get the solution later you will get the points!)

# %%
longGRB = pd.read_csv("https://raw.githubusercontent.com/fedhere/DSPS_2025_midterm/refs/heads/main/data/longGRBs.csv", skiprows=1)
longGRB = longGRB[["zc"]]
longGRB.rename({"zc": "Redshift"}, axis=1, inplace=True)
longGRB
# Out:
#      Redshift
# 0       1.752
# 1       2.571
# 2         NaN
# 3         NaN
# 4       1.522
# ...       ...
# 2778    0.835
# 2779      NaN
# 2780    0.695
# 2781      NaN
# 2782      NaN
#
# [2783 rows x 1 columns]

# %%
longGRB.describe()
# Out:
#        Redshift
# count       717
# unique      663
# top        <5.5
# freq          4

# %%
longGRB["Redshift"] = pd.to_numeric(longGRB["Redshift"], errors="coerce")
longGRB
# Out:
#       Redshift
# 0        1.752
# 1        2.571
# 2          NaN
# 3          NaN
# 4        1.522
# ...        ...
# 2778     0.835
# 2779       NaN
# 2780     0.695
# 2781       NaN
# 2782       NaN
#
# [2783 rows x 1 columns]

# %%
longGRB.dropna(inplace=True)
longGRB
# Out:
#       Redshift
# 0       1.7520
# 1       2.5710
# 4       1.5220
# 11      5.2600
# 18      0.9420
# ...        ...
# 2768    0.0085
# 2773    3.4200
# 2775    0.9578
# 2778    0.8350
# 2780    0.6950
#
# [568 rows x 1 columns]

# %% [markdown]
# ## 4 Separate the samples of EP transients and create a dataframe with only those with a coincident GRB detection
#
# call the sample `ep_GRB`
#
# [hints](https://docs.google.com/document/d/1KApJOkC7CWjXBhSQDavRmdhAkMD5z802zv5ikY9tw04/edit?tab=t.0#heading=h.isi30wsuhrhc)
#
# You can get the solution at this url: https://github.com/fedhere/DSPS_2025_midterm/tree/main/solutions - if you use this solution you will not get the 7 points for this deliverable (but you can go back later to this! and if you do get the solution later you will get the points!)

# %%
eptransients
# Out:
#           Name  Redshift GRB?
# 0    EP240315a     4.859  GRB
# 1    EP240414a     0.401  NaN
# 2    EP240801a     1.673  XRF
# 3    EP240804a     3.662  GRB
# 4    EP240806a     2.818  NaN
# 5    EP241021a     0.748  NaN
# 6   EP241030aa     1.411  GRB
# 7    EP241107a     0.456  NaN
# 8    EP241113a     1.530  NaN
# 9    EP241217a     4.590  NaN
# 10   EP241217b     1.879  GRB
# 11   EP250108a     0.176  NaN
# 12   EP250125a     2.890  NaN
# 13   EP250205a     3.550  GRB
# 14   EP250215a     4.610  GRB
# 15   EP250223a     2.756  NaN
# 16   EP250226a     3.315  GRB
# 17   EP250302a     1.131  NaN
# 18   EP250304a     0.200  NaN
# 19   EP250321a     4.368  NaN
# 20   EP250404a     2.627  GRB
# 21   EP250416a     0.963  GRB
# 22   EP250427a     1.520  GRB
# 23  EP250704ab     0.661  GRB
# 24   EP250821a     0.577  NaN
# 25   EP250827a     1.610  NaN

# %%
ep_GRB = eptransients[~eptransients["GRB?"].isna()]
ep_GRB.shape
# Out:
# (12, 3)

# %% [markdown]
# ## 5 Create a second EP transient sample with only no-GRB detection
#
# call the sampleand `ep_noGRB`
#
#
# [hint](https://docs.google.com/document/d/1KApJOkC7CWjXBhSQDavRmdhAkMD5z802zv5ikY9tw04/edit?tab=t.0#heading=h.isi30wsuhrhc)
#
#
# You can get the solution at this url: https://github.com/fedhere/DSPS_2025_midterm/tree/main/solutions - if you use this solution you will not get the 7 points for this deliverable (but you can go back later to this! and if you do get the solution later you will get the points!)

# %%
ep_noGRB = eptransients[eptransients["GRB?"].isna()]
ep_noGRB.shape
# Out:
# (14, 3)

# %% [markdown]
# ### validation
# if your files are incorrect in size use the solutions at https://github.com/fedhere/DSPS_2025_midterm/tree/main/solutions

# %%
#use this code to check your data file size. It should return
"""
eptransients has 26 rows
longGRB has 568 rows
shortGRB has 14 rows
ep_GRB has 12 rows
ep_noGRB has 14 rows
"""

for df,filename in zip([eptransients, longGRB, shortGRB, ep_GRB, ep_noGRB],
              ["eptransients", "longGRB", "shortGRB", "ep_GRB", "ep_noGRB"]
              ):
  print(f"{filename} has {df.shape[0]} rows")
# Out:
# eptransients has 26 rows
# longGRB has 568 rows
# shortGRB has 14 rows
# ep_GRB has 12 rows
# ep_noGRB has 14 rows

# %% [markdown]
# #PART II DATA EXPLORATION
#
# _The deliverable are not just plotted and printed values but also the discussions related to them_

# %% [markdown]
# ## 6  Plot the distribution of readshifts  for each of the  samples
#
#
# remember axis labels and captions! no captions no points!
#
# [hint](https://docs.google.com/document/d/1KApJOkC7CWjXBhSQDavRmdhAkMD5z802zv5ikY9tw04/edit?tab=t.0#heading=h.vu3ga15gdvc0)

# %%
seriesnames = ["eptransients", "longGRB", "shortGRB",
               "ep_GRB  ", "ep_noGRB"]
samples = [eptransients, longGRB, shortGRB,
               ep_GRB, ep_noGRB]

# %%
fig, axs = plt.subplots(3,2)
axs = axs.ravel()
for i,df in enumerate([eptransients, longGRB, shortGRB, ep_GRB, ep_noGRB]):
  df["Redshift"].hist(ax=axs[i], label=seriesnames[i])
  axs[i].set_xlabel("Redshift")
  if not i%2:
    axs[i].set_ylabel("Counts")
  axs[i].legend()

axs[-1].axis('off');
# Out:
# (np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(1.0))

# %% [markdown]
# Figure 1: histograms of the four distributions, as indicated in the legend, of soft Xray transients from the Einstein Probe (eptransients), long GRBs, short GRBs, and the subset of eptransients with GRBs (ep_GRB) and without (ep_noGRB).
#
# The longGRB distribution stands out for its smooth shape, due to the significantly larger number of samples in the distribution. It is skewed, with a right tail of redshift as high as 8. The other short GRB distribution, while noisier, clearly shows a shorter range of wavelengths and a mean at lower redshift values.
#
# The eptransients distribution, while noisy, looks roughly uniform in redshift and the subsets with and without GRBs do not show any obvious sign of being anything but a random sample out of eptransients.

# %% [markdown]
# ##  7 Calculate the central tendency readshift for each of the samples  and its uncertainty. Are the means consistent within the uncertainty with each other?
#
# Dont overthing this task: this is a quick comparison of distribution properties. Are they obviously differnt distributions or could they be the same (statistically?). This should not take you more than a few minutes.
# Ideally this shoudl be a well printed statement with the appropriate number of decimal digits...
#
#
# add plots as appropriate if you want, but it is not required, and chose your preferred way to measure the central tendency and spread

# %%
means, stds = [], []
print("          means, standard deviations")
for i,df in enumerate([eptransients, longGRB, shortGRB, ep_GRB, ep_noGRB]):
  means.append(df["Redshift"].mean())
  stds.append(df["Redshift"].std())
  print(seriesnames[i],"\t", f"{means[-1]:.2f}     {stds[-1]:.2f}, "
        f"range:{means[-1] - stds[-1]:.2f}-"
        f"{means[-1] + stds[-1]:.2f}")
# Out:
#           means, standard deviations
# eptransients 	 2.11     1.50, range:0.62-3.61
# longGRB 	 2.00     1.38, range:0.61-3.38
# shortGRB 	 0.73     0.40, range:0.33-1.14
# ep_GRB   	 2.56     1.42, range:1.14-3.98
# ep_noGRB 	 1.73     1.51, range:0.22-3.24

# %% [markdown]
# based on the 1-sigma ranges of each distribution, the samples are broadly consistent (the mean of each sample falls in the 1-sigma range of each other) except for shortGRB, whcih shows a smaller range around a small mean such that the mean of all other samples is outside of its 1-sigma range. ep_GRB also has a higher mean, but consistent with all other samples and marginally consisntent with shortGRB

# %% [markdown]
# **Extra credit: make a box and whiskers plot of the distributions**

# %%
# Combine the redshift data from all dataframes into a list
data_to_plot = [eptransients['Redshift'],
                longGRB['Redshift'],
                shortGRB['Redshift'],
                ep_GRB['Redshift'],
                ep_noGRB['Redshift']]

# Create the box and whiskers plot
plt.figure(figsize=(10, 6))
plt.boxplot(data_to_plot, labels=seriesnames, patch_artist=True)

plt.xlabel("Sample")
plt.ylabel("Redshift")
plt.title("Box and Whiskers Plot of Redshift Distributions")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /tmp/ipython-input-2117655188.py:10: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data_to_plot, labels=seriesnames, patch_artist=True)

# %% [markdown]
# From this plot, we can draw the same conclusion that we drew by observing the mean and standard deviation values. sortGRB stands out for having both a more compact distribution and a lower mean in redshift than all others

# %% [markdown]
# # PART III ANALYSIS
# _The code deliverable are printed p-values and their interpretations_

# %% [markdown]
# ## 8 Set up your Null Hypotesis Rejection testing framework.
#
# Describe the test you are about to run and why you choose it, and explicitly state its Null Hypothesis.
#
# Remember there are 6 steps in NHRT, the first 4 are the set up and should be done here! (slide deck 3 and 4)

# %% [markdown]
# With the idea in mind of assessing if there are statistically significant differences between different samples of transients, as far as their redshift go, with the goal of assessing if we can determin if eptransients or its ep_noGRB subset is a new class of objects:
#
# 1) Null Hypothesis: two distributions come from the same parent distributions (are identical)
# 2) Alternative Hypothesis: two distributions come from different parent distributions (are different)
# 3) Threshold: 95% or p-value < 0.05
# 4) KS test for samples

# %% [markdown]
# ## 9 Compare pairwise the distributions of redshifts of EP transients (`eptransients`), of short GRBs, and of long GRBs.   Discuss your findings. Only the sample statistically consistent with the EP tansients sample should be used in later tasks.
#
# You want to determine if they are the same (or more exactly "extracted from the same population", hint hint...!) with the NHRT test you chose above - are the EP transients consistent with either? with both? Establish this way if you should use the short or long GRB sample for the rest of the analysis
#
# [hint](https://docs.google.com/document/d/1KApJOkC7CWjXBhSQDavRmdhAkMD5z802zv5ikY9tw04/edit?tab=t.0#heading=h.pwkb8bo4nrla)
#
# **Extra Credit** define a function that given the 2 samples runs and interprets the test reporting the result automatically. That way you can use it for all sample comparisons and save time! but you do not have to for the grade
#
#
# **Extra Credit** if you have chosen the right statistical test, there is a plot that naturally goes with it and helps you visualize your findings. Add this plot (as seen in some homework)

# %%
# This cell is intentionally left empty as a placeholder for potential future code related to the KS test visualization.
# The visualization code is included within the getKSpvalue function in the next cell.

# %%
def getKSpvalue(samp1, samp2, s1name, s2name):
  ksresult = ks_2samp(samp1["Redshift"], samp2["Redshift"])[1]
  cancannot = "can" if ksresult < 0.05 else "cannot"
  print(f"We {cancannot} reject the null hypothesis that the samples are the same")
  ax = samp1.hist(cumulative=True, density=True, histtype='step', label=s1name)
  samp2.hist(cumulative=True, density=True, histtype='step', ax=ax, label=s2name)
  plt.legend()
  return ksresult


for i,s1 in enumerate(samples[:-2]):
  for j,s2 in enumerate(samples[i+1:-2]):
    print(seriesnames[i], seriesnames[i+j+1])
    print(f"p-value {getKSpvalue(s1,s2,seriesnames[i], seriesnames[i+j+1]):.2f}")
# Out:
# eptransients longGRB
# We cannot reject the null hypothesis that the samples are the same
# p-value 0.45
# eptransients shortGRB
# We can reject the null hypothesis that the samples are the same
# p-value 0.00
# longGRB shortGRB
# We can reject the null hypothesis that the samples are the same
# p-value 0.00

# %% [markdown]
# We can rule out the hypothesis that shortGRB redshift distribution is consistent with either longGRB or the EP soft Xray transients. Short GRB are a distinct population (p-value > 0.05)
#
# However, we cannot rule out that the soft X-ray EP transients redshift distribution is identical to the longGRB's one, implying that the EP transients may be the same class of objects as longGRBs.

# %% [markdown]
# ## 10 Compare the distribution of EP GRB transients with the sample you chose in step 9
#
# Here you use `ep_GRB`. Use your statistical test and accept/reject the null hypothesis accoringly.
#
# Discuss your findings!

# %%
print(f"p-value {getKSpvalue(ep_GRB, longGRB, "ep GRB", "long GRB"):.2f}");
# Out:
# We cannot reject the null hypothesis that the samples are the same
# p-value 0.32

# %% [markdown]
# We cannot rule out the hypothesis that the EP transients with GRB are from the same population as the longGRBs (pvalue = 0.05)

# %% [markdown]
# ## 11 Compare the distribution of EP with no GRB transients with the sample you chose in step 9
#
# Here you use `ep_GRB`. Use your statistical test and accept/reject the null hypothesis accoringly.
#
# Discuss your findings!

# %%
print(f"p-value {getKSpvalue(ep_noGRB, longGRB, "ep no GRB", "long GRB"):.2f}");
# Out:
# We cannot reject the null hypothesis that the samples are the same
# p-value 0.26

# %% [markdown]
# We cannot rule out the hypothesis that the EP transients without GRB are from the same population as the longGRBs (pvalue = 0.05)

# %% [markdown]
# ## 12 Frame your final answer on whether the distributions are different in terms of null hypothesis rejection and interpret the implications of this result in the light of the initial question describe in the DOMAIN CONTEXT section.

# %% [markdown]
# We cannot rule out that either EP transients with and EP transients without GRP are consistent with long GRBs, as far as the redshift distribution is concerned. Therefore, we cannot rule out that the EP Soft X-Ray transients, including those wihtout coincident GRB detection are just a manifestation of longGRBs are soft X-Ray wavelengths.

# %% [markdown]
#
# **Extra Credit.**
# Use the Anderson darling instead, which unlike the KS test is not biased to the central tendency of the distribution.

# %%
def getADpvalue(samp1, samp2):
  result = anderson_ksamp([samp1["Redshift"], samp2["Redshift"]])[2]
  cancannot = "can" if result < 0.05 else "cannot"
  print(f"We {cancannot} reject the null hypothesis that the samples are the same")
  return result


for i,s1 in enumerate(samples[:-2]):
  for j,s2 in enumerate(samples[i+1:-2]):
    print(seriesnames[i], seriesnames[i+j+1])
    print(f"p-value {getADpvalue(s1,s2):.2f}")

print(f"p-value {getADpvalue(ep_GRB, longGRB):.2f}");
print(f"p-value {getADpvalue(ep_noGRB, longGRB):.2f}");
# Out:
# eptransients longGRB
# We cannot reject the null hypothesis that the samples are the same
# p-value 0.25
# eptransients shortGRB
# We can reject the null hypothesis that the samples are the same
# p-value 0.00
# longGRB shortGRB
# We can reject the null hypothesis that the samples are the same
# p-value 0.00
# We cannot reject the null hypothesis that the samples are the same
# p-value 0.19
# We cannot reject the null hypothesis that the samples are the same
# p-value 0.20
# /tmp/ipython-input-3674756287.py:2: UserWarning: p-value capped: true value larger than 0.25. Consider specifying `method` (e.g. `method=stats.PermutationMethod()`.)
#   result = anderson_ksamp([samp1["Redshift"], samp2["Redshift"]])[2]
# /tmp/ipython-input-3674756287.py:2: UserWarning: p-value floored: true value smaller than 0.001. Consider specifying `method` (e.g. `method=stats.PermutationMethod()`.)
#   result = anderson_ksamp([samp1["Redshift"], samp2["Redshift"]])[2]

# %% [markdown]
# The AD test leads to the exact same hypothesis rejection but it is more sensitive to differences in the tail of the distribution
